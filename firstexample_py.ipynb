# %% [markdown]
# <a href="https://colab.research.google.com/github/shahzadokara/Bootcamp-Setup/blob/master/firstexample_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url = 'http://www.webscrapingfordatascience.com/basichttp/'
r = requests.get(url)
print(r.text)
# Out:
# Hello from the web!

# %%
url = 'http://www.webscrapingfordatascience.com/basichttp/'
r = requests.get(url)
print(r.status_code) # have more codes like 200, 402 means 'page not found error'
print(r.reason)
print(r.headers)
print(r.request)
print(r.request.headers)
print(r.text)
# Out:
# 200
# OK
# {'Date': 'Mon, 19 Apr 2021 17:39:33 GMT', 'Server': 'Apache/2.4.41 (Ubuntu)', 'Content-Length': '21', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8'}
# <PreparedRequest [GET]>
# {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
# Hello from the web!

# %%
url = 'https://www.jovian.ai/aakashns/python-web-scraping-project-guide'
r = requests.get(url)
print(r.status_code)
print(r.reason)
# Out:
# 404
# Not Found

# %%
url = 'http://www.webscrapingfordatascience.com/paramhttp/?query=test'
r = requests.get(url)
print(r.text)
# Out:
# I don't have any information on "test"

# %%
url = 'http://www.webscrapingfordatascience.com/paramhttp/?query=a query with spaces'
r = requests.get(url)
# Parameter will be encoded as 'a%20query%20with%20spaces'
# You can verify this be looking at the prepared request URL:
print(r.request.url) # when u want to find full URL with parameters from server end 
print(r.text)
# Out:
# http://www.webscrapingfordatascience.com/paramhttp/?query=a%20query%20with%20spaces
# I don't have any information on "a query with spaces"

# %%
url = 'http://www.webscrapingfordatascience.com/paramhttp/?query=complex?&'
# Parameter will not be encoded
r = requests.get(url)
# You can verify this be looking at the prepared request URL:
print(r.request.url)
# Will show [...]/paramhttp/?query=complex?&
print(r.text)
# Out:
# http://www.webscrapingfordatascience.com/paramhttp/?query=complex?&
# I don't have any information on "complex?"

# %%
from urllib.parse import quote, quote_plus
raw_string = 'a query with /, spaces and?&'
print(quote(raw_string))
print(quote_plus(raw_string))
# Out:
# a%20query%20with%20/%2C%20spaces%20and%3F%26
# a+query+with+%2F%2C+spaces+and%3F%26

# %%
from urllib.parse import quote, quote_plus
raw_string = 'a query with /, spaces and?&'
url = 'http://www.webscrapingfordatascience.com/paramhttp/?query='
print('\nUsing quote:')
# Nothing is safe, not even '/' characters, so encode everything
r = requests.get(url + quote(raw_string, safe=''))
print(r.url)
print(r.text)
# Out:
# Using quote:
# http://www.webscrapingfordatascience.com/paramhttp/?query=a%20query%20with%20%2F%2C%20spaces%20and%3F%26
# I don't have any information on "a query with /, spaces and?&"

# %%
print('\nUsing quote_plus:')
r = requests.get(url + quote_plus(raw_string))
print(r.url)
print(r.text)
# Out:
# Using quote_plus:
# http://www.webscrapingfordatascience.com/paramhttp/?query=+%2F%2C%3F%26
# I don't have any information on " /,?&"

# %%
url = 'http://www.webscrapingfordatascience.com/paramhttp/'
parameters = {
 'query': 'a query with /, spaces and?&'
 }
r = requests.get(url, params=parameters)
print(r.url)
print(r.text)
# Out:
# http://www.webscrapingfordatascience.com/paramhttp/?query=a+query+with+%2F%2C+spaces+and%3F%26
# I don't have any information on "a query with /, spaces and?&"

# %%
def calc(a, b, op):
 url = 'http://www.webscrapingfordatascience.com/calchttp/'
 params = {'a': a, 'b': b, 'op': op}
 r = requests.get(url, params=params)
 return r.text
print(calc(4, 6, '*'))
print(calc(4, 6, '/'))
# Out:
# 24
# 0.66666666666667

# %%
url = 'https://en.wikipedia.org/w/index.php' + \
 '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of Game of Thrones episodes - Wikipedia</title>
# ...

# %%
r = requests.get('https://api.github.com/user', auth=('user', 'pass'))
r.status_code
#print(r.text)
r.headers['content-type']
r.encoding
r.text
r.json()
# Out:
# {'documentation_url': 'https://docs.github.com/rest/reference/users#get-the-authenticated-user',
#  'message': 'Requires authentication'}

# %%
r = requests.get('https://api.github.com/events')
r.status_code
r.reason
r.links
r.url
r.raw
r.apparent_encoding
r.connection
r.content
r.cookies
r.history
r.headers
r.is_permanent_redirect
r.is_redirect
r.iter_content
r.text
# Out:
# '[{"id":"16001523529","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":251143069,"name":"magnusbrigido/semana_omnistack10","url":"https://api.github.com/repos/magnusbrigido/semana_omnistack10"},"payload":{"action":"opened","number":15,"pull_request":{"url":"https://api.github.com/repos/magnusbrigido/semana_omnistack10/pulls/15","id":618442230,"node_id":"MDExOlB1bGxSZXF1ZXN0NjE4NDQyMjMw","html_url":"https://github.com/magnusbrigido/semana_omnistack10/pull/15","diff_url":"https://github.com/magnusbrigido/semana_omnistack10/pull/15.diff","patch_url":"https://github.com/magnusbrigido/semana_omnistack10/pull/15.patch","issue_url":"https://api.github.com/repos/magnusbrigido/semana_omnistack10/issues/15","number":15,"state":"open","locked":false,"title":"Bump ssri from 6.0.1 to 6.0.2 in /fr
# ...

# %%
r = requests.put('https://httpbin.org/post', data = {'key':'value'})
r.headers
r.text
r.content
r.status_code
r.reason
r.raise_for_status
r.status_code
r.reason
# Out:
# 'METHOD NOT ALLOWED'

# %%
url = 'https://en.wikipedia.org/w/index.php' + \
 '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of Game of Thrones episodes - Wikipedia</title>
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/w/index.php' + \
 '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_contents = r.text
#html_soup = BeautifulSoup(html_contents)
html_soup = BeautifulSoup(html_contents, 'html.parser')
first_h1 = html_soup.find('h1')
print(first_h1.name) 
print(first_h1.contents)
# Out:
# h1
# ['List of ', <i>Game of Thrones</i>, ' episodes']

# %%
print(str(first_h1))
print(first_h1.get_text()) # same as .text
# Out:
# <h1 class="firstHeading" id="firstHeading">List of <i>Game of Thrones</i> episodes</h1>
# List of Game of Thrones episodes

# %%
print(first_h1.get_text())
print(first_h1.attrs)
print(first_h1.attrs['id']) #same 
print(first_h1['id'])       #same result as above 
print(first_h1.get('id'))    #same resutl as above
# Out:
# List of Game of Thrones episodes
# {'id': 'firstHeading', 'class': ['firstHeading']}
# firstHeading
# firstHeading
# firstHeading

# %%
cites = html_soup.find_all('cite', class_='citation', limit=5)
for citation in cites:
  print(citation)
# Out:
# <cite class="citation web cs1" id="CITEREFFowler2011">Fowler, Matt (April 8, 2011). <a class="external text" href="https://web.archive.org/web/20120817073932/http://tv.ign.com/articles/116/1160215p1.html" rel="nofollow">"Game of Thrones: "Winter is Coming" Review"</a>. <a href="/wiki/IGN" title="IGN">IGN</a>. Archived from <a class="external text" href="http://tv.ign.com/articles/116/1160215p1.html" rel="nofollow">the original</a> on August 17, 2012<span class="reference-accessdate">. Retrieved <span class="nowrap">September 22,</span> 2016</span>.</cite>
# ...

# %%
cites = html_soup.find_all('cite', class_='citation',limit=3)
for citation in cites:
  print(citation.get_text())
# Out:
# Fowler, Matt (April 8, 2011). "Game of Thrones: "Winter is Coming" Review". IGN. Archived from the original on August 17, 2012. Retrieved September 22, 2016.
# Fleming, Michael (January 16, 2007). "HBO turns Fire into fantasy series". Variety. Archived from the original on May 16, 2012. Retrieved September 3, 2016.
# "Game of Thrones". Emmys.com. Retrieved September 17, 2016.

# %%
cites = html_soup.find_all('cite', class_='citation', limit=3)
for citation in cites:
  print(citation.text)
  link = citation.find('a') # Inside of this cite element, find the first a tag
  print(link.get('href')) # ..and show its URL
  print()
# Out:
# Fowler, Matt (April 8, 2011). "Game of Thrones: "Winter is Coming" Review". IGN. Archived from the original on August 17, 2012. Retrieved September 22, 2016.
# https://web.archive.org/web/20120817073932/http://tv.ign.com/articles/116/1160215p1.html
#
# Fleming, Michael (January 16, 2007). "HBO turns Fire into fantasy series". Variety. Archived from the original on May 16, 2012. Retrieved September 3, 2016.
# https://web.archive.org/web/20120516224747/http://www.variety.com/article/VR1117957532?refCatId=14
#
# "Game of Thrones". Emmys.com. Retrieved September 17, 2016.
# http://www.emmys.com/shows/game-thrones

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/w/index.php' + \
'?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_contents = r.text
html_soup = BeautifulSoup(html_contents, 'html.parser')
# We'll use a list to store our episode list
episodes = []
ep_tables = html_soup.find_all('table', class_='wikitable plainrowheaders wikiepisodetable')
for table in ep_tables:
    headers = []
    rows = table.find_all('tr')
    # Start by fetching the header cells from the first row to determine
    # the field names
    for header in table.find('tr').find_all('th'):
        headers.append(header.text)
    # Then go through all the rows except the first one
    for row in table.find_all('tr')[1:]:
        values = []
        # And get the column cells, the first one being inside a th-tag
        for col in row.find_all(['th','td']):
            values.append(col.text)
        if values:
            episode_dict = {headers[i]: values[i] for i in
        range(len(values))}
        episodes.append(episode_dict)
# Show the results
for episode in episodes:
 print(episode)
# Out:
# {'No.overall': '1', 'No. inseason': '1', 'Title': '"Winter Is Coming"', 'Directed by': 'Tim Van Patten', 'Written by': 'David Benioff & D. B. Weiss', 'Original air date\u200a[20]': 'April\xa017,\xa02011\xa0(2011-04-17)', 'U.S. viewers(millions)': '2.22[21]'}
# {'No.overall': '2', 'No. inseason': '2', 'Title': '"The Kingsroad"', 'Directed by': 'Tim Van Patten', 'Written by': 'David Benioff & D. B. Weiss', 'Original air date\u200a[20]': 'April\xa024,\xa02011\xa0(2011-04-24)', 'U.S. viewers(millions)': '2.20[22]'}
# {'No.overall': '3', 'No. inseason': '3', 'Title': '"Lord Snow"', 'Directed by': 'Brian Kirk', 'Written by': 'David Benioff & D. B. Weiss', 'Original air date\u200a[20]': 'May\xa01,\xa02011\xa0(2011-05-01)', 'U.S. viewers(millions)': '2.44[23]'}
# ...

# %%
url = 'https://en.wikipedia.org/w/index.php' + \
'?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_contents = r.text
html_soup = BeautifulSoup(html_contents, 'html.parser')
print(html_soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Game of Thrones episodes - Wikipedia</title>
# ...
